# %% [markdown]
# 1. Install comyx
# 2. Define Simulation Parameters (num_users, channel_model, ...)
# 3. Generate User Profiles
# 4. Simulate NOMA Transmissions
# 5. Format the results
# 6. Save the dataset

# %%
# !pip install comyx
# !pip install tqdm
# Out:
# Collecting comyx
#   Downloading comyx-0.2.5-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from comyx) (1.26.4)
# Requirement already satisfied: numba>=0.54.1 in /usr/local/lib/python3.11/dist-packages (from comyx) (0.60.0)
# Requirement already satisfied: pandas>=2.0.1 in /usr/local/lib/python3.11/dist-packages (from comyx) (2.2.2)
# Requirement already satisfied: scipy>=1.11.1 in /usr/local/lib/python3.11/dist-packages (from comyx) (1.13.1)
# Requirement already satisfied: mpmath>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from comyx) (1.3.0)
# Collecting colorama>=0.4.6 (from comyx)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: matplotlib>=3.5.1 in /usr/local/lib/python3.11/dist-packages (from comyx) (3.10.0)
# Requirement already satisfied: pyarrow>=14.0.0 in /usr/local/lib/python3.11/dist-packages (from comyx) (17.0.0)
# Requirement already satisfied: python-box>=7.1.1 in /usr/local/lib/python3.11/dist-packages (from comyx) (7.3.2)
# Requirement already satisfied: termcolor>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from comyx) (2.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.1->comyx) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.1->comyx) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.1->comyx) (4.55.7)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.1->comyx) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.1->comyx) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.1->comyx) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.1->comyx) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.1->comyx) (2.8.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.54.1->comyx) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.1->comyx) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.1->comyx) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5.1->comyx) (1.17.0)
# Downloading comyx-0.2.5-py3-none-any.whl (25 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: colorama, comyx
# Successfully installed colorama-0.4.6 comyx-0.2.5
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)

# %% [markdown]
# #Importing Necessary Libraries

# %%
from comyx.network import UserEquipment, BaseStation, Link
from comyx.propagation import get_noise_power
from comyx.utils import dbm2pow, get_distance, generate_seed, db2pow
from scipy.optimize import minimize


import numpy as np
from numba import jit
from matplotlib import pyplot as plt

# %% [markdown]
# #Setting Up Environment

# %%
# Pt = np.linspace(-10, 30, 80)  # dBm
#pt_lin = dbm2pow(Pt)  # Watt
Pt = np.array([20]) # dBm
Pt_lin = dbm2pow(Pt)  # Watt
bandwidth = 1e7  # Bandwidth in Hz
frequency = 2.4e9  # Carrier frequency
temperature = 300  # Kelvin # 300
mc = 3  # Number of channel realizations
simulation_area_size = 50  # Size of square area (units)
max_distance_bs_ue = 50     # Maximum distance from BS to each UE (units) # 50
max_distance_ue_ue = 20      # Maximum distance between UEs (units) # 20
quantization_factor = 0.1  # Quantization factor
num_steps = int(1 / quantization_factor) + 1  # Number of steps

allocation_factors = np.linspace(0.01, 0.49, 1000) # All allocation factors for UEn and UEf
#allocation_factors = [0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3, 0.34, 0.4, 0.45]
N0 = get_noise_power(temperature, bandwidth)  # dBm
N0_lin = dbm2pow(N0)  # Watt

R_prime_n = 0
R_prime_f = 0

n_antennas = 1

fading_args = {"type": "rayleigh", "sigma": 1 / 3}
pathloss_args = {
    "type": "reference",
    "alpha": 3.5, #3.5
    "p0": 30, # 20
    "frequency": frequency,
}  # p0 is the reference power in dBm

# %% [markdown]
# #Network Setup

# %%
# Function to check feasibility of generated locations for UEs
def is_feasible(bs_position, ue1_position, ue2_position, size_area, max_dist_bs_ue, max_dist_ue_ue):
    # Check if BS and UEs are within the area bounds
    if (abs(bs_position[0]) > size_area / 2 or abs(bs_position[1]) > size_area / 2 or
        abs(ue1_position[0]) > size_area / 2 or abs(ue1_position[1]) > size_area / 2 or
        abs(ue2_position[0]) > size_area / 2 or abs(ue2_position[1]) > size_area / 2):
        return False

    # Check distances from BS to UEs
    if (get_distance(bs_position, ue1_position) > max_dist_bs_ue or
        get_distance(bs_position, ue2_position) > max_dist_bs_ue):
        return False

    # Check distance between UEs
    if get_distance(ue1_position, ue2_position) > max_dist_ue_ue:
        return False


    #print(get_distance(bs_position, ue1_position) , get_distance(bs_position, ue2_position))

    return True

# Initialize Setup
def initialize():
  # Initialize Base Station position
  BS = BaseStation("BS", position=[0, 0, 10], n_antennas=n_antennas, t_power=Pt_lin)

  # Loop until valid positions for UEn and UEf are found
  valid_positions_found = False
  while not valid_positions_found:
      # Generate random positions for UEn and UEf within specified constraints
      UEn_position = [np.random.uniform(-max_distance_bs_ue, max_distance_bs_ue),
                      np.random.uniform(-max_distance_bs_ue, max_distance_bs_ue),
                      1]

      UEf_position = [np.random.uniform(-max_distance_bs_ue, max_distance_bs_ue),
                      np.random.uniform(-max_distance_bs_ue, max_distance_bs_ue),
                      1]

      # ADDITIONAL - if they are not at same distances
      # UEf_position = UEn_position

      # Check if all positions are feasible
      valid_positions_found = is_feasible(BS.position, UEn_position, UEf_position,
                                          simulation_area_size, max_distance_bs_ue, max_distance_ue_ue)

  # Initialize User Equipments with their feasible positions
  UEn = UserEquipment("UEn", position=UEn_position, n_antennas=n_antennas)
  UEf = UserEquipment("UEf", position=UEf_position, n_antennas=n_antennas)

  return BS, UEn, UEf

# %% [markdown]
# #Initialize Links

# %%
def initialize_links(BS, UEn, UEf):
  # Shapes for channels
  shape_bu = (n_antennas, n_antennas, mc)

  # Links
  # fmt: off
  link_bs_uen = Link(
      BS, UEn,
      fading_args, pathloss_args,
      shape=shape_bu, seed=generate_seed("BS-UEn"),
  )

  link_bs_uef = Link(
      BS, UEf,
      fading_args, pathloss_args,
      shape=shape_bu, seed=generate_seed("BS-UEf"),
  )

  return link_bs_uen, link_bs_uef

# %% [markdown]
# #Compute Rates & Spectral Efficiency

# %%
def computeRates(BS, UEn, UEf, allocation_factors, link_bs_uen, link_bs_uef):
  results = []
  sample_index = 0

  # Looping over each allocation factor
  for alloc_UEn in allocation_factors:
      alloc_UEf = 1 - alloc_UEn

      # Update the power allocations for BS
      BS.allocations = {"UEn": alloc_UEn, "UEf": alloc_UEf}

      UEn.sinr_pre = np.zeros((len(Pt), mc))
      UEn.sinr = np.zeros((len(Pt), mc))
      UEf.sinr = np.zeros((len(Pt), mc))
      SE_nf = np.zeros((len(Pt), mc))
      SE_n = np.zeros((len(Pt), mc))
      SE_f = np.zeros((len(Pt), mc))
      SE_total = np.zeros((len(Pt), mc))
      R_n = np.zeros((len(Pt), mc))
      R_f = np.zeros((len(Pt), mc))


      # Get channel gains
      gain_f = link_bs_uef.magnitude**2
      gain_n = link_bs_uen.magnitude**2


      # Loop over each power level
      for i, p in enumerate(Pt_lin):
          p = BS.t_power[i]

          # Loop over each channel realization
          for k in range(mc):
              gain_f_scalar = gain_f[0, 0, k]
              gain_n_scalar = gain_n[0, 0, k]

              # Effective transmit powers for each user
              P_n = BS.allocations["UEn"] * p   # Effective power for near user
              P_f = BS.allocations["UEf"] * p   # Effective power for far user

              # Computing Rates
              R_n[i, k] = P_n * gain_n_scalar  # Data rate for near user (received power)
              R_f[i, k] = P_f * gain_f_scalar    # Data rate for far user (received power)

              if R_n[i,k] < R_prime_n or R_f[i,k] < R_prime_f:
                  continue  # Skip this allocation if QoS is not met

              sample_index = sample_index + 1

              # Edge user
              UEf.sinr[i, k] = (BS.allocations["UEf"] * p * gain_f_scalar) / (
                  BS.allocations["UEn"] * p * gain_f_scalar + N0_lin
              )

              # Center user
              UEn.sinr_pre[i, k] = (BS.allocations["UEf"] * p * gain_n_scalar) / (
                  BS.allocations["UEn"] * p * gain_n_scalar + N0_lin
              )
              UEn.sinr[i, k] = (BS.allocations["UEn"] * p * gain_n_scalar) / N0_lin

              # Spectral Efficiencies
              SE_nf[i, k] = np.log2(1 + UEn.sinr_pre[i, k])
              SE_n[i, k] = np.log2(1 + UEn.sinr[i, k])
              SE_f[i, k] = np.log2(1 + UEf.sinr[i, k])

              # Total spectral efficiency
              SE_total[i, k] = SE_n[i, k] + SE_f[i, k]


      # se_index = np.unravel_index(np.argmax(SE_total), SE_total.shape)

      # Finding the optimal transmit power and channel realization for this power-allocation ensuring QOS
      max_se_index = np.unravel_index(np.argmax(SE_total), SE_total.shape)
      optimal_power_index = max_se_index[0]
      optimal_channel_index = max_se_index[1]

      optimal_power = Pt[optimal_power_index]
      max_spectral_efficiency = SE_total[max_se_index]

      # Extract channel realization values for the optimal channel
      optimal_gain_f = gain_f[0, 0, optimal_channel_index]
      optimal_gain_n = gain_n[0, 0, optimal_channel_index]

      # Store results including allocation coefficients and max spectral efficiency
      results.append({
          'sample index' : sample_index,
          'alloc_UEn': alloc_UEn,
          'alloc_UEf': alloc_UEf,
          'operational_power': int(optimal_power),
          "R_n": R_n[i, k],
          "R_f": R_f[i, k],
          'max_spectral_efficiency': max_spectral_efficiency,
          'optimal_gain_f': optimal_gain_f,
          'optimal_gain_n': optimal_gain_n,
          'optimal_channel_index': optimal_channel_index,
          'optimal_power_index': optimal_power_index,
      })

  return results

# %% [markdown]
# # Optimal Channel Realization

# %%
def find_optimal_results(results):
  # Initialize an empty list to store the optimal results
  optimal_results = []

  # Find the entry with the maximum spectral efficiency
  best_result = max(results, key=lambda x: x['max_spectral_efficiency'])

  # Append the best result to the optimal_results array
  optimal_results.append(best_result)

  return optimal_results

# %%
# Print the optimal results
def print_optimal_results(optimal_results):
  for res in optimal_results:
      print(f"Optimal Allocation Factors: UEn={res['alloc_UEn']:.2f}, UEf={res['alloc_UEf']:.2f}")
      print("Operational Power:", res['operational_power'])
      print("Maximum Spectral Efficiency:", res['max_spectral_efficiency'])
      print("Optimal Channel Realization Values:")
      print("  Gain for UEf (edge user):", res['optimal_gain_f'])
      print("  Gain for UEn (center user):", res['optimal_gain_n'])

# %%
# Print ALL the results
def printResults(results):
  for idx, res in enumerate(results):
      print(f"Result {idx + 1}:")
      print(f"\tAllocation Factors:")
      print(f"\t  UEn: {res['alloc_UEn']:}")
      print(f"\t  UEf: {res['alloc_UEf']:}")
      print(f"\tOperational Power: {res['optimal_power']} dBm")
      print(f"\tMaximum Spectral Efficiency: {res['max_spectral_efficiency']:} bps/Hz")
      print(f"\tOptimal Channel Realization Values:")
      print(f"\t  Gain for UEf (edge user): {res['optimal_gain_f']:}")
      print(f"\t  Gain for UEn (center user): {res['optimal_gain_n']:}")
      print("\n" + "-" * 40 + "\n")

# %% [markdown]
# # Running Code

# %%
import json
from tqdm import tqdm

# Function to write JSON data to a single file
def write_json_file(data, filename):
    with open(filename, 'w') as json_file:
        json.dump(data, json_file, indent=4)

# Initialize a list to store all runs' data
data = []

# Number of rows of data for simulation
rows_of_data = 10

# Running for multiple network configurations
for i in tqdm(range(rows_of_data)):
    # Initialize the setup
    BS, UEn, UEf = initialize()

    # Initialize Links
    link_bs_uen, link_bs_uef = initialize_links(BS, UEn, UEf)

    # Compute SE for each transmit power for each channel realization for each pair of power_coefficients
    results = computeRates(BS, UEn, UEf, allocation_factors, link_bs_uen, link_bs_uef)

    # Find optimal results
    optimal_run_results = find_optimal_results(results)


    # Prepare data for this run
    run_data = {
        "sample index": i,
        # "channel_arrays": [
        #     link_bs_uen.magnitude.tolist(),  # Channel matrix values for BS-UEn
        #     link_bs_uef.magnitude.tolist()   # Channel matrix values for BS-UEf
        # ],
        # "transmit_power (Watt)": BS.t_power.max(),  # Total transmit power of the BS
        # "pa_factors_against_that_transmit_power": [
        #     res['alloc_UEn'] * BS.t_power.max() for res in optimal_run_results  # Power allocated to UEn based on max transmit power
        # ],
        "optimal_results": [
            {
                "alloc_UEn": res['alloc_UEn'],
                "alloc_UEf": res['alloc_UEf'],
                "operational_power": res['operational_power'],
                "max_spectral_efficiency": res['max_spectral_efficiency'],
                "optimal_gain_f": res['optimal_gain_f'],
                "optimal_gain_n": res['optimal_gain_n']
            }
            for res in optimal_run_results  # Loop through optimal results
        ]
    }

    # for res in optimal_run_results:
    #   if res['alloc_UEn'] != 0.05 and res['alloc_UEn'] != 0.45:
    #     print(res['alloc_UEn'], res['alloc_UEf'])

    # Append this run's data to the list of all runs' data
    data.append(run_data)

# Write all runs' data to a single JSON file at the end of all simulations
write_json_file(data, 'SE_data.json')
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 12.13it/s]

# %% [markdown]
# #Archived

# %%
optimal_results = []

# Running for multiple network configs
for i in range(rows_of_data):

  # Initialize the setup
  BS, UEn, UEf = initialize()

  # Initialize Links
  link_bs_uen, link_bs_uef = initialize_links(BS, UEn, UEf)

  # Compute SE for each transmit power for each channel realization for each pair of power_coefficients
  results = computeRates(BS, UEn, UEf, allocation_factors, link_bs_uen, link_bs_uef)

  # Find optimal results
  optimal_results.append(find_optimal_results(results))

  # Print optimal results
  print_optimal_results(optimal_results[i])
  print()

print(len(optimal_results))
# Out:
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 24.93382505954232
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 0.00010105170782633299
#   Gain for UEn (center user): 1.3274941262454525e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 26.049629424118145
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 9.915464418064006e-05
#   Gain for UEn (center user): 2.876894422938893e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 23.741858630171123
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 4.089010066812762e-06
#   Gain for UEn (center user): 5.810534986347449e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 23.324267245091804
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.7002816161762056e-06
#   Gain for UEn (center user): 4.35019405729883e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 28.626853178911567
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.427646930357998e-05
#   Gain for UEn (center user): 0.00017169040745414283
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 25.41533425767177
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 5.403268603772453e-05
#   Gain for UEn (center user): 1.8534541958647098e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.957229289419164
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 7.613387112419508e-06
#   Gain for UEn (center user): 2.6984176498343828e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.7466953957847
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.817882483524498e-06
#   Gain for UEn (center user): 2.3320194808928443e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 28.917504118092353
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.9599165102417594e-05
#   Gain for UEn (center user): 0.0002100103431163394
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 27.911767886349715
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.306382539211333e-05
#   Gain for UEn (center user): 0.0001045884935898498
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 28.52826301984162
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 4.03036228406903e-06
#   Gain for UEn (center user): 0.00016034945003421408
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 28.179114844294308
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 8.240069240563979e-06
#   Gain for UEn (center user): 0.000125881925297242
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.316460337431366
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.1966189931567326e-06
#   Gain for UEn (center user): 8.65343435536845e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 26.070112369655305
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.189955502422201e-06
#   Gain for UEn (center user): 2.918034330969173e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.827608466169366
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.388563864592879e-06
#   Gain for UEn (center user): 1.2332736568878888e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 27.429053851015208
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.811364311000431e-05
#   Gain for UEn (center user): 7.484667281121704e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 27.06613476040497
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.3720779787005215e-06
#   Gain for UEn (center user): 5.8200004225052964e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 24.66476683333613
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 0.00010272356087290393
#   Gain for UEn (center user): 1.1016350136140234e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 27.14596501727897
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 5.336794479147935e-05
#   Gain for UEn (center user): 6.151120945864233e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 25.6223324319006
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 8.281690435709053e-05
#   Gain for UEn (center user): 2.1394125175648027e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 26.698471845338748
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.7680855198732195e-06
#   Gain for UEn (center user): 4.5107155691541535e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 23.00239501710375
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.4496500292103586e-06
#   Gain for UEn (center user): 3.4802893974049024e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 27.33519847694158
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.258020622963618e-06
#   Gain for UEn (center user): 7.013249574942095e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 27.065460296727583
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.4699472074697486e-05
#   Gain for UEn (center user): 5.817279619965714e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.19299866810639
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 8.072065724495596e-06
#   Gain for UEn (center user): 1.5887399535969964e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.79259339072933
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.240068113391021e-06
#   Gain for UEn (center user): 2.407403470691694e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 27.754104680195574
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 0.00011703833094334986
#   Gain for UEn (center user): 9.376106015021352e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 28.516513673689545
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.501346097272265e-06
#   Gain for UEn (center user): 0.00015904886567754184
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.878317254974128
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 7.2587191023147385e-06
#   Gain for UEn (center user): 1.2773922291157249e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.343670179109637
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.095729196102616e-06
#   Gain for UEn (center user): 8.818190662882729e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 26.828299156418904
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.69988135320867e-06
#   Gain for UEn (center user): 4.93545685006683e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 28.652532509448502
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.0246640661508465e-05
#   Gain for UEn (center user): 0.00017477378459206317
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.61445497775618
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 5.057497444115702e-06
#   Gain for UEn (center user): 1.0638828673962444e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.405147209028204
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 4.24290623240737e-06
#   Gain for UEn (center user): 9.20207778744117e-06
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 22.78400873636977
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 7.1786331643242525e-06
#   Gain for UEn (center user): 2.9913763510514066e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.095544624019013
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.833486464873682e-06
#   Gain for UEn (center user): 1.4849651136339598e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 26.545615161207607
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.4237311693360278e-05
#   Gain for UEn (center user): 4.057242427718994e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 26.300716560795852
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 7.230271776460453e-05
#   Gain for UEn (center user): 3.4238036498937485e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 26.89918525593287
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 4.432871518783079e-06
#   Gain for UEn (center user): 5.1840143316694577e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 23.478895193747395
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.3642723221500008e-06
#   Gain for UEn (center user): 4.842350920452672e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.58476802287048
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.1258139793578907e-06
#   Gain for UEn (center user): 1.042214649556805e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 24.913353365156244
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 6.317882356779607e-05
#   Gain for UEn (center user): 1.3087903986781387e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.583521053768244
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 6.184888135513563e-06
#   Gain for UEn (center user): 1.041314147006863e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.30272514103843
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 6.120372248475022e-06
#   Gain for UEn (center user): 8.571439596598443e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 23.69871149170388
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.855487372309942e-06
#   Gain for UEn (center user): 5.639330379838874e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 26.127269005923054
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 7.004818593295532e-06
#   Gain for UEn (center user): 3.0359612746777524e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 26.132198064822667
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 0.00014001421816350952
#   Gain for UEn (center user): 3.046348215484508e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 22.642362318050402
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.687090907830811e-06
#   Gain for UEn (center user): 2.7116458217695676e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.90178491141346
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 5.996029849428437e-06
#   Gain for UEn (center user): 1.298340917676124e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.187613309013287
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.5048395169341901e-05
#   Gain for UEn (center user): 1.5828204468677278e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.8827644873033
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.4396450241711078e-06
#   Gain for UEn (center user): 2.5626722071778033e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.926654105429584
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 7.460610226308814e-06
#   Gain for UEn (center user): 1.3209157300346968e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 25.37736766135079
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.7582153171749055e-05
#   Gain for UEn (center user): 1.805315303738769e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.41762757078061
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 8.647131441578801e-06
#   Gain for UEn (center user): 1.8564055438378183e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 23.90501467041821
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 5.382346167979423e-05
#   Gain for UEn (center user): 6.506217329444967e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.065984967035266
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.4364145849804497e-06
#   Gain for UEn (center user): 7.274244455336554e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 26.035647404556403
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.8174503930789434e-06
#   Gain for UEn (center user): 2.8491509090480613e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 23.798063630953536
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.801097153392577e-05
#   Gain for UEn (center user): 6.041336410871758e-06
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 24.0332499325514
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 8.196587046842083e-05
#   Gain for UEn (center user): 7.1110109603055715e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 27.473373482902186
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.1044799455933502e-05
#   Gain for UEn (center user): 7.718164845095692e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 23.990819627493792
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 6.2839150563748405e-06
#   Gain for UEn (center user): 6.9049548388637795e-06
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 24.194863017957918
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 4.749901001820402e-05
#   Gain for UEn (center user): 7.953937244868707e-06
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 23.34059432487016
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 4.77416334475898e-05
#   Gain for UEn (center user): 4.399667235528751e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.563691629729078
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 4.811015421291287e-06
#   Gain for UEn (center user): 2.054199120282226e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 23.177657082979255
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.935055039905255e-06
#   Gain for UEn (center user): 3.929836633762847e-06
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 24.31809186545184
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.2790780582340258e-05
#   Gain for UEn (center user): 8.663199810433186e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 23.50114052308915
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.559722392426603e-06
#   Gain for UEn (center user): 4.917595611524206e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 27.9714204292571
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.8521371828407976e-05
#   Gain for UEn (center user): 0.00010900366859524564
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 25.615185795461393
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.8261182885278894e-05
#   Gain for UEn (center user): 2.1288427924133025e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 23.614049054040926
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.745133630003049e-05
#   Gain for UEn (center user): 5.317884344519363e-06
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 25.60947603645985
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.5735991432852743e-05
#   Gain for UEn (center user): 2.1204344001715245e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 23.82019916683704
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 5.2223420666540025e-05
#   Gain for UEn (center user): 6.1347433444442455e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 27.29402055618003
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 5.151109810898787e-05
#   Gain for UEn (center user): 6.815903379045148e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 24.384935366375576
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 4.470332780377108e-05
#   Gain for UEn (center user): 9.074024363235631e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 27.9584021164122
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.3622928691151685e-05
#   Gain for UEn (center user): 0.00010802448631435693
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 24.933627690802084
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.206821992257007e-05
#   Gain for UEn (center user): 1.3273144571891727e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 26.83205553774363
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.1967972479787842e-05
#   Gain for UEn (center user): 4.948323769175697e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 23.698538523410043
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.1634519854227473e-05
#   Gain for UEn (center user): 5.638632975423784e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 27.201461725885498
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.3187039083701501e-05
#   Gain for UEn (center user): 6.392348607445538e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 25.14030846269931
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 9.115170659377689e-05
#   Gain for UEn (center user): 1.5317592299050175e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 29.01426191049304
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 6.472535907714365e-06
#   Gain for UEn (center user): 0.00022457825438343157
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 25.29029240153063
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.226173234039524e-05
#   Gain for UEn (center user): 1.6995762084205846e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 23.707661688898117
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.7070184691143903e-06
#   Gain for UEn (center user): 5.674424456334441e-06
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 23.30422410936004
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 5.9278595216679374e-05
#   Gain for UEn (center user): 4.2901366686493476e-06
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 25.04097537081043
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 4.431842357851293e-05
#   Gain for UEn (center user): 1.4298431149074314e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 28.375264873048444
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 0.0001328853523608252
#   Gain for UEn (center user): 0.00014421498793324675
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.28842237797633
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.7213903996610027e-06
#   Gain for UEn (center user): 1.697376961983441e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 26.190883282074456
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 0.00012675932697426724
#   Gain for UEn (center user): 3.172821149299629e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 26.168776017352005
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 7.566596149350057e-06
#   Gain for UEn (center user): 3.124575919569117e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.575269677569274
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.2490099237957096e-05
#   Gain for UEn (center user): 2.07075088100938e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.732942807157045
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 9.096737403182074e-06
#   Gain for UEn (center user): 1.1549473645546875e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.156852117008135
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 4.762638175275614e-06
#   Gain for UEn (center user): 7.747143801512248e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.624385987777735
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 7.44179081864308e-06
#   Gain for UEn (center user): 2.1424630875748513e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 23.775793282671007
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 5.794947325184253e-06
#   Gain for UEn (center user): 5.9488286101975085e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 27.880901556203305
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 6.895056724165682e-06
#   Gain for UEn (center user): 0.00010237460416036358
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 26.448921061327432
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 9.430619762414887e-06
#   Gain for UEn (center user): 3.794225513038074e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 23.16556236170671
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.594293523945054e-05
#   Gain for UEn (center user): 3.896997936250697e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 27.14853817985768
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.1057776924999285e-05
#   Gain for UEn (center user): 6.162101830731161e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.707188163190846
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.6926589935374878e-06
#   Gain for UEn (center user): 2.2690254816143173e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.866933784425797
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 5.470963969696937e-06
#   Gain for UEn (center user): 1.2673527512288268e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.324247723912535
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.083144433146042e-05
#   Gain for UEn (center user): 1.7400539596558407e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 24.785584491041384
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 5.921980186500867e-05
#   Gain for UEn (center user): 1.197864593694613e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 24.282795560698325
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.3881935328192834e-05
#   Gain for UEn (center user): 8.453820021007378e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.50922987125247
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.3982595798535329e-05
#   Gain for UEn (center user): 1.9780983913328105e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.500632795479298
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 6.867174168867649e-06
#   Gain for UEn (center user): 1.966345940137084e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 26.45556852518012
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.4215857422760184e-05
#   Gain for UEn (center user): 3.811748288081807e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 24.512226136708403
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.1258686115855884e-05
#   Gain for UEn (center user): 9.91103221492189e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.712972130724236
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 6.878533881241402e-06
#   Gain for UEn (center user): 1.139070031125082e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.852561331098695
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.3245520232159666e-06
#   Gain for UEn (center user): 1.2547899118098463e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 28.299581756315675
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.3314052277807416e-05
#   Gain for UEn (center user): 0.00013684455326292745
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 26.49846389784118
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 6.631187921456488e-06
#   Gain for UEn (center user): 3.926784142808079e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.629336936732752
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 9.87014186400278e-06
#   Gain for UEn (center user): 2.1498280557324104e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 23.401941699156158
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 4.9871677677324785e-06
#   Gain for UEn (center user): 4.5908235218887724e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.232606465919723
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.926753686483788e-06
#   Gain for UEn (center user): 1.6329618065538943e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.268773349204892
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 4.824150292551957e-06
#   Gain for UEn (center user): 8.37207804955042e-06
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 25.364096315092517
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.0899427008917958e-05
#   Gain for UEn (center user): 1.7887851780431605e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 23.82543795468822
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.988014857579435e-06
#   Gain for UEn (center user): 6.157097858369385e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 26.026181241845837
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.200502166180852e-06
#   Gain for UEn (center user): 2.8305172719206712e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 28.80145547154085
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 5.849891962551161e-06
#   Gain for UEn (center user): 0.00019377894325823283
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 23.267522194368958
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 7.924320023716978e-06
#   Gain for UEn (center user): 4.182390592637346e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.773261816655385
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.4145692065994167e-05
#   Gain for UEn (center user): 2.375359941041213e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.577937783221163
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 4.197195928333584e-06
#   Gain for UEn (center user): 1.037292053660137e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 23.79936071045792
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.048228887284272e-05
#   Gain for UEn (center user): 6.046776039226317e-06
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 23.454633734299563
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.5924324228016913e-05
#   Gain for UEn (center user): 4.7615652262530665e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.66293400817988
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.4704526239432224e-06
#   Gain for UEn (center user): 1.10024030126441e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 23.786316041969073
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.2903057231724627e-06
#   Gain for UEn (center user): 5.992377612954032e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 26.58736685033717
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.3219443685846193e-06
#   Gain for UEn (center user): 4.176375476260838e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 27.573314984656093
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.5654786539638784e-05
#   Gain for UEn (center user): 8.271788672230939e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 24.11199152857391
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 4.051543906030893e-05
#   Gain for UEn (center user): 7.5099195903048505e-06
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 23.068749494567328
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 9.389726493100812e-06
#   Gain for UEn (center user): 3.6440729128749854e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 23.366567966067436
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.93089022031628e-06
#   Gain for UEn (center user): 4.479632697013736e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 28.480556773706702
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.030575218636331e-05
#   Gain for UEn (center user): 0.0001551337984604043
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 26.34744569351063
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 7.709428810028417e-06
#   Gain for UEn (center user): 3.536519150638889e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 25.623263640588277
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.4557138137431353e-05
#   Gain for UEn (center user): 2.1407963959151887e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 24.832383272421044
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 9.091710230107291e-05
#   Gain for UEn (center user): 1.2373583925664911e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.490031118976606
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 5.787050507321358e-06
#   Gain for UEn (center user): 1.9519491879348884e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 25.502410252743644
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.713889186398496e-05
#   Gain for UEn (center user): 1.9687688427706022e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 23.837246790739243
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.628282619847808e-06
#   Gain for UEn (center user): 6.207701534368537e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 26.2811033233488
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 6.968519005822486e-06
#   Gain for UEn (center user): 3.377574777857884e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 24.21668236757503
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 4.3997453952317284e-05
#   Gain for UEn (center user): 8.075148221431322e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.234151390404897
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 4.134665564085532e-06
#   Gain for UEn (center user): 8.17355568495276e-06
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 23.764792357709307
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 7.469465799115408e-05
#   Gain for UEn (center user): 5.90360197313809e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.411552977043492
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 8.67837050335127e-06
#   Gain for UEn (center user): 1.848605418210807e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.862991701310264
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.8919267597911752e-05
#   Gain for UEn (center user): 2.5277889583715707e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.44371852886146
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.46863734504831e-06
#   Gain for UEn (center user): 1.890284285274213e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.4176860685774
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.2705944262422074e-06
#   Gain for UEn (center user): 9.282404428729203e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 23.286967263257964
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.78367040784521e-06
#   Gain for UEn (center user): 4.2391633770338775e-06
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 26.393786231931045
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 0.00012824890158168566
#   Gain for UEn (center user): 3.651956019158962e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 26.61176812660006
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.9002459545325654e-05
#   Gain for UEn (center user): 4.247613401601401e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 22.619232783681802
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.877969962310478e-06
#   Gain for UEn (center user): 2.6685265686676858e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 28.7165590623641
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 9.192882393763686e-06
#   Gain for UEn (center user): 0.0001827049045610413
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 26.489861337288904
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.1676280018255389e-05
#   Gain for UEn (center user): 3.903438915550024e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 25.30553775690857
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 5.51143948106411e-05
#   Gain for UEn (center user): 1.7176304652299616e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 24.044502544199542
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.7954829076467098e-05
#   Gain for UEn (center user): 7.166704797599322e-06
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 23.864082098678175
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.712250931532453e-05
#   Gain for UEn (center user): 6.324216129268192e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.69595688342169
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 7.475373922672459e-06
#   Gain for UEn (center user): 1.1257146638725486e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 24.479780191662684
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.3520651105471892e-05
#   Gain for UEn (center user): 9.690632481850483e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 27.664182389048218
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 8.686174204855847e-06
#   Gain for UEn (center user): 8.809540559384372e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 27.01711142014386
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.114453088119607e-05
#   Gain for UEn (center user): 5.6255562736669135e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 26.425092691307295
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 0.00011568842228352765
#   Gain for UEn (center user): 3.732069713809177e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 27.018331178897565
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 4.690393113728415e-06
#   Gain for UEn (center user): 5.6303149398753256e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.70251070501643
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 9.739649246794696e-06
#   Gain for UEn (center user): 2.2616803587280107e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 23.526321841748356
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.6112181351337155e-06
#   Gain for UEn (center user): 5.004182528109461e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 26.721978503025852
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.619975975141018e-05
#   Gain for UEn (center user): 4.584812795098164e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 23.75006776833835
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.0337300557963198e-05
#   Gain for UEn (center user): 5.843673989023849e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 22.827888466017132
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.67201799024397e-06
#   Gain for UEn (center user): 3.083782192668201e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 26.901240577176786
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.36189128961607e-05
#   Gain for UEn (center user): 5.191404539739637e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 23.59212729461976
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.0842476364429319e-06
#   Gain for UEn (center user): 5.2377240903323696e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.50233905938701
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.186880648240796e-06
#   Gain for UEn (center user): 1.9686730403706895e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 23.329981377386666
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.405393319275425e-05
#   Gain for UEn (center user): 4.367429253353733e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 27.726461493602688
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 7.598471306908904e-05
#   Gain for UEn (center user): 9.19816337401697e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 26.61428945444665
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.9242772375587407e-05
#   Gain for UEn (center user): 4.255043238067998e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 25.129391825035224
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.428163972413495e-05
#   Gain for UEn (center user): 1.5202135029289566e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 26.392886759430038
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 4.532835959872823e-05
#   Gain for UEn (center user): 3.649681987454635e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 27.43711268812379
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 8.150801330985691e-06
#   Gain for UEn (center user): 7.526593637830658e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.80645658848411
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.50343868832776e-06
#   Gain for UEn (center user): 2.4306482350330122e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 28.81748457745769
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.87328622692264e-05
#   Gain for UEn (center user): 0.00019594392484672496
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 24.974353619421525
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 4.6700560940281987e-05
#   Gain for UEn (center user): 1.3653159474095712e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.033441174543718
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 8.182978870799824e-06
#   Gain for UEn (center user): 1.4223982938523733e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.174860477396628
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 6.493977173873707e-06
#   Gain for UEn (center user): 7.84445297908318e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.394534142073226
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 5.726401294239669e-06
#   Gain for UEn (center user): 1.8269264044742997e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 28.92378918876229
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 6.261978882849675e-06
#   Gain for UEn (center user): 0.00021092725443499745
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 23.259578930424382
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.656900942079205e-06
#   Gain for UEn (center user): 4.159446155777003e-06
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 25.53044948937216
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 6.171518803496514e-05
#   Gain for UEn (center user): 2.007405126650815e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 27.20070009605937
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 4.272138375026471e-06
#   Gain for UEn (center user): 6.388975275177177e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 24.49227566887708
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.4032196997895876e-05
#   Gain for UEn (center user): 9.774912057366885e-06
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 23.548726927384227
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.1597729089139979e-05
#   Gain for UEn (center user): 5.08248023597905e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# ...
#   Gain for UEf (edge user): 4.925488968817045e-06
#   Gain for UEn (center user): 3.6688843825159917e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.442697096927798
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.996098187725352e-06
#   Gain for UEn (center user): 9.444729986670732e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.159793535180942
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.1304741502558643e-06
#   Gain for UEn (center user): 1.5525912720607577e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 24.902649565929735
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 0.00011837895426072916
#   Gain for UEn (center user): 1.2991155884856426e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 23.364893995301
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 9.69824222462828e-06
#   Gain for UEn (center user): 4.474415301458041e-06
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 23.689880386394833
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 5.700452653952916e-06
#   Gain for UEn (center user): 5.604915145313959e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 28.802058020187612
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.232251533111595e-05
#   Gain for UEn (center user): 0.00019385988538212135
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.860516426836995
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 4.0606232533606184e-06
#   Gain for UEn (center user): 1.261727900197397e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.992500923355184
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.5423603453919196e-06
#   Gain for UEn (center user): 2.765203118657319e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 28.83972066261937
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 7.779215083466836e-06
#   Gain for UEn (center user): 0.00019898738540335327
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.430513802693497
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.3800160706786067e-06
#   Gain for UEn (center user): 1.87306148161407e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 27.160767814589803
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 8.485466937245724e-05
#   Gain for UEn (center user): 6.214558424414201e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 24.80708435194934
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 6.93399045902793e-05
#   Gain for UEn (center user): 1.2158494695569752e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 22.981003476355006
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 5.437791630966478e-06
#   Gain for UEn (center user): 3.4290509917546057e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 23.494240673581654
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.257143477017414e-06
#   Gain for UEn (center user): 4.894132392955256e-06
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 23.497226172085
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 5.48641966108992e-06
#   Gain for UEn (center user): 4.904265892644079e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.349725373194467
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 5.107576224128684e-06
#   Gain for UEn (center user): 8.855279147062306e-06
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 23.787005504713164
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 7.717269221902383e-06
#   Gain for UEn (center user): 5.995232202698544e-06
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 24.700405471106784
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.8264592196057965e-05
#   Gain for UEn (center user): 1.1291887074617582e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.21689555692361
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.43203574677371e-06
#   Gain for UEn (center user): 1.6152752154894673e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 28.559389400162217
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 7.055693862033143e-06
#   Gain for UEn (center user): 0.00016384659821670557
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 26.226624154798877
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 0.00011508551746774178
#   Gain for UEn (center user): 3.2524055588173864e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 23.24928025702644
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 4.646178804028027e-06
#   Gain for UEn (center user): 4.12985448505509e-06
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 26.252491615632476
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 4.5475375159934965e-05
#   Gain for UEn (center user): 3.3112488690927396e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.45063528472216
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.0418235396638775e-06
#   Gain for UEn (center user): 1.8993684030725182e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 24.024196080973976
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.0943283814666364e-05
#   Gain for UEn (center user): 7.066547153781837e-06
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 23.0673479079338
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 9.305814467210729e-06
#   Gain for UEn (center user): 3.6405344970828413e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 26.669464183190023
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.70876452573202e-05
#   Gain for UEn (center user): 4.420925756428733e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 27.776765907623727
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 8.514378432271454e-05
#   Gain for UEn (center user): 9.524545404571138e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.774937665911885
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 8.81347844182147e-06
#   Gain for UEn (center user): 1.1890603729831198e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 24.12580849202702
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 8.068441935613486e-06
#   Gain for UEn (center user): 7.582220287124314e-06
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 25.21599736008167
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.949662995357914e-05
#   Gain for UEn (center user): 1.6142690211043202e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.830959193969335
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.1304508001074036e-05
#   Gain for UEn (center user): 1.2361411466578514e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 22.963257701448477
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.230695294674175e-06
#   Gain for UEn (center user): 3.387145706034109e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.394025455930215
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.5194600888874203e-06
#   Gain for UEn (center user): 9.13141177861625e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.353375765314283
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.8474203750958577e-06
#   Gain for UEn (center user): 8.877714991941477e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.79431626156655
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.2714721567150711e-05
#   Gain for UEn (center user): 2.410279734564116e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 22.534786367508527
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.41952036389154e-06
#   Gain for UEn (center user): 2.5168139439575488e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 23.6948802947541
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 5.568419863501419e-06
#   Gain for UEn (center user): 5.6243743392366535e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.947195082016652
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.5291832263388113e-05
#   Gain for UEn (center user): 2.6797147019890024e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 23.84262143289662
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.7511633824855406e-05
#   Gain for UEn (center user): 6.230844227711447e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.412979481684395
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 5.560582467009959e-06
#   Gain for UEn (center user): 1.8504342335632943e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 23.497860761006688
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 4.531334816658733e-06
#   Gain for UEn (center user): 4.906427963562402e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.26303652021425
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 4.396489119139654e-06
#   Gain for UEn (center user): 8.338852931143439e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.990032134048384
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.844926214734835e-06
#   Gain for UEn (center user): 2.7604750957782966e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 24.245823180852007
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.6785411108323907e-05
#   Gain for UEn (center user): 8.239928861639748e-06
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 22.840259086521918
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.574277445124909e-05
#   Gain for UEn (center user): 3.1103050033584387e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.731078753532294
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.1175797089310435e-05
#   Gain for UEn (center user): 1.1534560525613775e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 23.841704263476704
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 8.337380525098819e-06
#   Gain for UEn (center user): 6.226900348993337e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 26.45301348895435
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 4.8739605788774755e-06
#   Gain for UEn (center user): 3.805003863187863e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 22.573009746748692
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.5600400810481883e-05
#   Gain for UEn (center user): 2.584349814088692e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.66913208655162
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.243689747885033e-06
#   Gain for UEn (center user): 1.1049771891822323e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 23.11338837451744
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.178739487408148e-06
#   Gain for UEn (center user): 3.7586137724762937e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.272348328208174
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.6178885759536234e-05
#   Gain for UEn (center user): 1.6785699141106133e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 23.656030505618844
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.7849024827854434e-06
#   Gain for UEn (center user): 5.474939642958603e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 26.33432591638332
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.4053867133480835e-05
#   Gain for UEn (center user): 3.504503972957486e-05
#
# Optimal Allocation Factors: UEn=0.01, UEf=0.99
# Operational Power: 20
# Maximum Spectral Efficiency: 23.044296691402586
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.9972461419840965e-05
#   Gain for UEn (center user): 3.5828171465088122e-06
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 27.681942892217805
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.3691328641742684e-06
#   Gain for UEn (center user): 8.918662664331682e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.601617823015644
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 5.996142840699632e-06
#   Gain for UEn (center user): 1.0544583746667042e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 24.984970575395792
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 1.3505743337147485e-05
#   Gain for UEn (center user): 1.3754034473829606e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 26.23388614152663
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.298637902010121e-05
#   Gain for UEn (center user): 3.268821198668804e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 25.16478098555226
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 3.1406025170686213e-06
#   Gain for UEn (center user): 1.55796782497487e-05
#
# Optimal Allocation Factors: UEn=0.49, UEf=0.51
# Operational Power: 20
# Maximum Spectral Efficiency: 28.419676880582838
# Optimal Channel Realization Values:
#   Gain for UEf (edge user): 2.052078081147787e-05
#   Gain for UEn (center user): 0.00014872355300698888
#
# 500

# %%
def find_optimal_results(results):
    # Now find which power coefficients give the optimal transmit power
    optimal_results = []
    max_se = max(result['max_spectral_efficiency'] for result in results)
    for result in results:
        if np.isclose(result['max_spectral_efficiency'], max_se, atol=1e-6):
            optimal_results.append(result)
            break  # Stop after finding the first optimal result

    return optimal_results

# %%
def computeRates(BS, UEn, UEf, allocation_factors, link_bs_uen, link_bs_uef):
    results = []
    sample_index = 0

    # Looping over each allocation factor
    for alloc_UEn in allocation_factors:
        alloc_UEf = 1 - alloc_UEn

        # Update the power allocations for BS
        BS.allocations = {"UEn": alloc_UEn, "UEf": alloc_UEf}

        UEn.sinr_pre = np.zeros((len(Pt), mc))
        UEn.sinr = np.zeros((len(Pt), mc))
        UEf.sinr = np.zeros((len(Pt), mc))
        SE_nf = np.zeros((len(Pt), mc))
        SE_n = np.zeros((len(Pt), mc))
        SE_f = np.zeros((len(Pt), mc))
        SE_total = np.zeros((len(Pt), mc))
        R_n = np.zeros((len(Pt), mc))
        R_f = np.zeros((len(Pt), mc))

        # Get channel gains
        gain_f = link_bs_uef.magnitude**2
        gain_n = link_bs_uen.magnitude**2

        # Loop over each power level
        for i, p in enumerate(Pt_lin):
            p = BS.t_power[i]

            # Loop over each channel realization
            for k in range(mc):
                gain_f_scalar = gain_f[0, 0, k]
                gain_n_scalar = gain_n[0, 0, k]

                # Effective transmit powers for each user
                P_n = BS.allocations["UEn"] * p   # Effective power for near user
                P_f = BS.allocations["UEf"] * p   # Effective power for far user

                # Computing Rates
                R_n[i, k] = P_n * gain_n_scalar  # Data rate for near user (received power)
                R_f[i, k] = P_f * gain_f_scalar    # Data rate for far user (received power)

                if R_n[i, k] < R_prime_n or R_f[i, k] < R_prime_f:
                    continue  # Skip this allocation if QoS is not met

                sample_index = sample_index + 1

                # Edge user
                UEf.sinr[i, k] = (P_f * gain_f_scalar) / (P_n * gain_f_scalar + N0_lin)

                # Center user
                UEn.sinr_pre[i, k] = (P_f * gain_n_scalar) / (P_n * gain_n_scalar + N0_lin)
                UEn.sinr[i, k] = (P_n * gain_n_scalar) / N0_lin

                # Spectral Efficiencies
                SE_nf[i, k] = np.log2(1 + UEn.sinr_pre[i, k])
                SE_n[i, k] = np.log2(1 + UEn.sinr[i, k])
                SE_f[i, k] = np.log2(1 + UEf.sinr[i, k])

                # Total spectral efficiency
                SE_total[i, k] = SE_n[i, k] + SE_f[i, k]

                # Debug prints
                print(f"alloc_UEn: {alloc_UEn}, alloc_UEf: {alloc_UEf}")
                print(f"R_n: {R_n[i, k]}, R_f: {R_f[i, k]}")
                print(f"SE_n: {SE_n[i, k]}, SE_f: {SE_f[i, k]}, SE_total: {SE_total[i, k]}")

        # Finding the optimal transmit power and channel realization for this power-allocation ensuring QOS
        max_se_index = np.unravel_index(np.argmax(SE_total), SE_total.shape)
        optimal_power_index = max_se_index[0]
        optimal_channel_index = max_se_index[1]

        optimal_power = Pt[optimal_power_index]
        max_spectral_efficiency = SE_total[max_se_index]

        # Extract channel realization values for the optimal channel
        optimal_gain_f = gain_f[0, 0, optimal_channel_index]
        optimal_gain_n = gain_n[0, 0, optimal_channel_index]

        # Store results including allocation coefficients and max spectral efficiency
        results.append({
            'sample index': sample_index,
            'alloc_UEn': alloc_UEn,
            'alloc_UEf': alloc_UEf,
            'operational_power': int(optimal_power),
            "R_n": R_n[i, k],
            "R_f": R_f[i, k],
            'max_spectral_efficiency': max_spectral_efficiency,
            'optimal_gain_f': optimal_gain_f,
            'optimal_gain_n': optimal_gain_n,
            'optimal_channel_index': optimal_channel_index,
            'optimal_power_index': optimal_power_index,
        })

    return results
